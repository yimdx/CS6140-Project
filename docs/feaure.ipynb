# %%
from sentence_transformers import SentenceTransformer
import numpy as np

# 1. 选择一个已有的预训练模型
#    英文示例: "sentence-transformers/all-MiniLM-L6-v2"
#    中文示例: "uer/sbert-base-chinese-nli"  (或其他中文SBERT模型)
model_name = "sentence-transformers/all-MiniLM-L6-v2"
model = SentenceTransformer(model_name)

# 2. 准备一些测试句子
sentences = [
    "I love natural language processing.",
    "The weather is nice today.",
    "I enjoy working with text data."
]

# 3. 编码句子，得到句向量
sentence_embeddings = model.encode(sentences)

# 4. 查看结果
for idx, sentence in enumerate(sentences):
    print(f"Sentence: {sentence}")
    print(f"Vector shape: {sentence_embeddings[idx].shape}")
    print(f"Vector (first 10 dims): {sentence_embeddings[idx][:10]}\n")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/transformers/utils/import_utils.py:1976, in _LazyModule._get_module(self, module_name)
#    1975 try:
# -> 1976     return importlib.import_module("." + module_name, self.__name__)
#    1977 except Exception as e:
#
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/transformers/generation/utils.py:30
#      28 from torch.nn import functional as F
# ---> 30 from transformers.generation.candidate_generator import AssistantVocabTranslatorCache
#      32 from ..cache_utils import (
#      33     Cache,
#      34     DynamicCache,
#    (...)
#      38     StaticCache,
#      39 )
#
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/transformers/generation/candidate_generator.py:27
#      26 if is_sklearn_available():
# ---> 27     from sklearn.metrics import roc_curve
#      29 from ..cache_utils import DynamicCache
#
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/sklearn/__init__.py:73
#      69 from . import (  # noqa: F401 E402
#      70     __check_build,
#      71     _distributor_init,
#      72 )
# ---> 73 from .base import clone  # noqa: E402
#      74 from .utils._show_versions import show_versions  # noqa: E402
#
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/sklearn/base.py:19
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#      20 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
#
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/sklearn/utils/__init__.py:15
#      14 from ._bunch import Bunch
# ---> 15 from ._chunking import gen_batches, gen_even_slices
#      16 from ._estimator_html_repr import estimator_html_repr
#
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/sklearn/utils/_chunking.py:11
#      10 from .._config import get_config
# ---> 11 from ._param_validation import Interval, validate_params
#      14 def chunk_generator(gen, chunksize):
#
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:14
#      13 import numpy as np
# ---> 14 from scipy.sparse import csr_matrix, issparse
#      16 from .._config import config_context, get_config
#
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/scipy/sparse/__init__.py:283
#     282 # For backward compatibility with v0.19.
# --> 283 from . import csgraph
#     285 # Deprecated namespaces, to be removed in v2.0.0
#
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/scipy/sparse/csgraph/__init__.py:185
#     159 __all__ = ['connected_components',
#     160            'laplacian',
#     161            'shortest_path',
#    (...)
#     182            'csgraph_to_masked',
#     183            'NegativeCycleError']
# --> 185 from ._laplacian import laplacian
#     186 from ._shortest_path import (
#     187     shortest_path, floyd_warshall, dijkstra, bellman_ford, johnson,
#     188     NegativeCycleError
#     189 )
#
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/scipy/sparse/csgraph/_laplacian.py:7
#       6 from scipy.sparse import isspmatrix
# ----> 7 from scipy.sparse.linalg import LinearOperator
#      10 ###############################################################################
#      11 # Graph laplacian
#
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/scipy/sparse/linalg/__init__.py:120
#       1 """
#       2 Sparse linear algebra (:mod:`scipy.sparse.linalg`)
#       3 ==================================================
#    (...)
#     117
#     118 """
# --> 120 from ._isolve import *
#     121 from ._dsolve import *
#
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/scipy/sparse/linalg/_isolve/__init__.py:4
#       3 #from info import __doc__
# ----> 4 from .iterative import *
#       5 from .minres import minres
#
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/scipy/sparse/linalg/_isolve/iterative.py:9
#       7 import numpy as np
# ----> 9 from . import _iterative
#      11 from scipy.sparse.linalg._interface import LinearOperator
#
# ImportError: dlopen(/opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/scipy/sparse/linalg/_isolve/_iterative.cpython-39-darwin.so, 0x0002): Library not loaded: @rpath/liblapack.3.dylib
#   Referenced from: <E6989187-D3E8-3103-BF0F-DABB04B74846> /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/scipy/sparse/linalg/_isolve/_iterative.cpython-39-darwin.so
#   Reason: tried: '/opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/scipy/sparse/linalg/_isolve/liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/scipy/sparse/linalg/_isolve/../../../../../../liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/scipy/sparse/linalg/_isolve/liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/scipy/sparse/linalg/_isolve/../../../../../../liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/surprise_env/bin/../lib/liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/surprise_env/bin/../lib/liblapack.3.dylib' (no such file), '/usr/local/lib/liblapack.3.dylib' (no such file), '/usr/lib/liblapack.3.dylib' (no such file, not in dyld cache)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/transformers/utils/import_utils.py:1976, in _LazyModule._get_module(self, module_name)
#    1975 try:
# -> 1976     return importlib.import_module("." + module_name, self.__name__)
#    1977 except Exception as e:
#
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/transformers/models/auto/modeling_auto.py:22
#      21 from ...utils import logging
# ---> 22 from .auto_factory import (
#      23     _BaseAutoBackboneClass,
#      24     _BaseAutoModelClass,
#      25     _LazyAutoMapping,
#      26     auto_class_update,
#      27 )
#      28 from .configuration_auto import CONFIG_MAPPING_NAMES
#
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/transformers/models/auto/auto_factory.py:40
#      39 if is_torch_available():
# ---> 40     from ...generation import GenerationMixin
#      43 logger = logging.get_logger(__name__)
#
# File <frozen importlib._bootstrap>:1055, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/transformers/utils/import_utils.py:1964, in _LazyModule.__getattr__(self, name)
#    1963 elif name in self._class_to_module.keys():
# -> 1964     module = self._get_module(self._class_to_module[name])
#    1965     value = getattr(module, name)
#
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/transformers/utils/import_utils.py:1978, in _LazyModule._get_module(self, module_name)
#    1977 except Exception as e:
# -> 1978     raise RuntimeError(
#    1979         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1980         f" traceback):\n{e}"
#    1981     ) from e
#
# RuntimeError: Failed to import transformers.generation.utils because of the following error (look up to see its traceback):
# dlopen(/opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/scipy/sparse/linalg/_isolve/_iterative.cpython-39-darwin.so, 0x0002): Library not loaded: @rpath/liblapack.3.dylib
#   Referenced from: <E6989187-D3E8-3103-BF0F-DABB04B74846> /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/scipy/sparse/linalg/_isolve/_iterative.cpython-39-darwin.so
#   Reason: tried: '/opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/scipy/sparse/linalg/_isolve/liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/scipy/sparse/linalg/_isolve/../../../../../../liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/scipy/sparse/linalg/_isolve/liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/scipy/sparse/linalg/_isolve/../../../../../../liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/surprise_env/bin/../lib/liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/surprise_env/bin/../lib/liblapack.3.dylib' (no such file), '/usr/local/lib/liblapack.3.dylib' (no such file), '/usr/lib/liblapack.3.dylib' (no such file, not in dyld cache)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from sentence_transformers import SentenceTransformer
#       2 import numpy as np
#       4 # 1. 选择一个已有的预训练模型
#       5 #    英文示例: "sentence-transformers/all-MiniLM-L6-v2"
#       6 #    中文示例: "uer/sbert-base-chinese-nli"  (或其他中文SBERT模型)
#
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/sentence_transformers/__init__.py:14
#       7 import os
#       9 from sentence_transformers.backend import (
#      10     export_dynamic_quantized_onnx_model,
#      11     export_optimized_onnx_model,
#      12     export_static_quantized_openvino_model,
#      13 )
# ---> 14 from sentence_transformers.cross_encoder import (
#      15     CrossEncoder,
#      16     CrossEncoderModelCardData,
#      17     CrossEncoderTrainer,
#      18     CrossEncoderTrainingArguments,
#      19 )
#      20 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#      21 from sentence_transformers.LoggingHandler import LoggingHandler
#
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/sentence_transformers/cross_encoder/__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .CrossEncoder import CrossEncoder
#       4 from .model_card import CrossEncoderModelCardData
#       5 from .trainer import CrossEncoderTrainer
#
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:15
#      13 from torch import nn
#      14 from tqdm.autonotebook import trange
# ---> 15 from transformers import (
#      16     AutoConfig,
#      17     AutoModelForSequenceClassification,
#      18     AutoTokenizer,
#      19     PretrainedConfig,
#      20     PreTrainedModel,
#      21 )
#      22 from transformers.utils import PushToHubMixin
#      23 from typing_extensions import deprecated
#
# File <frozen importlib._bootstrap>:1055, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/transformers/utils/import_utils.py:1965, in _LazyModule.__getattr__(self, name)
#    1963 elif name in self._class_to_module.keys():
#    1964     module = self._get_module(self._class_to_module[name])
# -> 1965     value = getattr(module, name)
#    1966 elif name in self._modules:
#    1967     value = self._get_module(name)
#
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/transformers/utils/import_utils.py:1964, in _LazyModule.__getattr__(self, name)
#    1962     value = Placeholder
#    1963 elif name in self._class_to_module.keys():
# -> 1964     module = self._get_module(self._class_to_module[name])
#    1965     value = getattr(module, name)
#    1966 elif name in self._modules:
#
# File /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/transformers/utils/import_utils.py:1978, in _LazyModule._get_module(self, module_name)
#    1976     return importlib.import_module("." + module_name, self.__name__)
#    1977 except Exception as e:
# -> 1978     raise RuntimeError(
#    1979         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1980         f" traceback):\n{e}"
#    1981     ) from e
#
# RuntimeError: Failed to import transformers.models.auto.modeling_auto because of the following error (look up to see its traceback):
# Failed to import transformers.generation.utils because of the following error (look up to see its traceback):
# dlopen(/opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/scipy/sparse/linalg/_isolve/_iterative.cpython-39-darwin.so, 0x0002): Library not loaded: @rpath/liblapack.3.dylib
#   Referenced from: <E6989187-D3E8-3103-BF0F-DABB04B74846> /opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/scipy/sparse/linalg/_isolve/_iterative.cpython-39-darwin.so
#   Reason: tried: '/opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/scipy/sparse/linalg/_isolve/liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/scipy/sparse/linalg/_isolve/../../../../../../liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/scipy/sparse/linalg/_isolve/liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/surprise_env/lib/python3.9/site-packages/scipy/sparse/linalg/_isolve/../../../../../../liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/surprise_env/bin/../lib/liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/surprise_env/bin/../lib/liblapack.3.dylib' (no such file), '/usr/local/lib/liblapack.3.dylib' (no such file), '/usr/lib/liblapack.3.dylib' (no such file, not in dyld cache)
